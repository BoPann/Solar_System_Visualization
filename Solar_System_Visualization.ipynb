# %% [markdown]
# # Solar System Visualization 🪐

# %% [markdown]
# ## Objectives
# - Create a Python program to visualize the solar system
# - Utilize the `matplotlib`, `numpy`, and `mpl_toolkits` libraries
# - Create a 2D visualization of the Solar System
# - Create a 3D visualization of the Solar System

# %% [markdown]
# ## Conceptual Space Knowledge 🌍
# Before diving into the project, let's cover the following concepts.
#
# Our solar system is comprised of the following components:
#
# ### **Sun**:
# - The Sun is a G-type star that is the central body of the solar system
#
# ### **Planets**:
#
# Our solar system consists of 8 planets which can be categorized as terrestrial and gas giants.
#
# **Terrestrial Planets**:
#
# - Mercury
# - Venus
# - Earth
# - Mars
#
# **Gas Giants**:
#
# - Jupiter
# - Saturn
# - Uranus
# - Neptune
#
# ### **Dwarf Planets**:
#
# - Pluto
#
# ### **Moons and Natural Satellites**:
#
# - Moons:
# Notable moons include Titan, Europa, and Ganymede.
#
# ## **Asteroids, Comets, and Kuiper Belt Objects**:
#
# - Asteroids:
# Rocky objects that orbit the Sun, primarily found in the asteroid belt between Mars and Jupiter.
#
# - Comets:
# Icy bodies with highly elliptical orbits that originate from the Kuiper Belt or Oort Cloud.
#
# - Kuiper Belt Objects:
# Objects in the Kuiper Belt beyond Neptune's orbit, including dwarf planets like Pluto and Eris.
#
# ![https://upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Solar_System_true_color_%28captions%29.jpg/600px-Solar_System_true_color_%28captions%29.jpg](https://upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Solar_System_true_color_%28captions%29.jpg/600px-Solar_System_true_color_%28captions%29.jpg)
#
# [Image Source](https://en.wikipedia.org/wiki/Solar_System)
#
# ### Orbital Details for each Planet

# %% [markdown]
# | Planet   | Orbital Period (Earth Years) | Eccentricity | Inclination (Degrees) |
# |----------|------------------------------|--------------|-----------------------|
# | Mercury  | 0.24                         | 0.2056       | 7.005                 |
# | Venus    | 0.62                         | 0.0067       | 3.394                 |
# | Earth    | 1.0                          | 0.0167       | 0                     |
# | Mars     | 1.88                         | 0.0934       | 1.850                 |
# | Jupiter  | 11.86                        | 0.0489       | 1.305                 |
# | Saturn   | 29.46                        | 0.0565       | 2.485                 |
# | Uranus   | 84.01                        | 0.0461       | 0.772                 |
# | Neptune  | 164.8                        | 0.0086       | 1.769                 |

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Define data for planets
planet_names = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
semi_major_axis = [0.39, 0.72, 1.0, 1.52, 5.2, 9.58, 19.22, 30.05]  # in AU (astronomical units)
orbit_period = [0.24, 0.62, 1.0, 1.88, 11.86, 29.46, 84.01, 164.8]  # in years

# %% [markdown]
# # Plotting Orbits in 2D
# Since the eccentricity and inclination of each of the planets (see above) is quite low, we can treat each of their orbital paths as circles.
#
# The code below demonstrates how to visualize each of the planet orbital paths using `matplotlib` and `numpy`.
#
# We place the Sun at the center using the method:
#
# ```
# ax.scatter(0, 0, color='yellow', s=100, label='Sun')
# ```
#
# We plot each of the planet orbits by treating them as circles with two core components:
# - Orbital Radius (aka Semi Major Axis)
#
# ```
# orbit_radius = semi_major_axis[i]
# ```
#
# - Orbital Angle:
# ```
# # generates 100 equally spaced points between 0 and 2π, covering a full circle
# orbit_theta = np.linspace(0, 2*np.pi, 100)
#
# # calculates the x-coordinates of points on the orbit
# x = orbit_radius * np.cos(orbit_theta)
#
# # calculates the y-coordinates of points on the orbit
# y = orbit_radius * np.sin(orbit_theta)
# ```

# %%
plt.style.use('dark_background')
# Create figure and axis
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the Sun at the center
ax.scatter(0, 0, color='yellow', s=100, label='Sun')

# Plot orbits of planets
for i, planet in enumerate(planet_names):
    orbit_radius = semi_major_axis[i]
    orbit_theta = np.linspace(0, 2*np.pi, 100)
    x = orbit_radius * np.cos(orbit_theta)
    y = orbit_radius * np.sin(orbit_theta)
    ax.plot(x, y, label=planet)

# Set aspect ratio to equal, and add labels
ax.set_aspect('equal', 'box')
ax.set_xlabel('Distance (AU)')
ax.set_ylabel('Distance (AU)')
ax.set_title('Solar System')
ax.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# # Your Turn: Plotting Orbits in 3D

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math

# INPUT YOUR CODE HERE: Create a figure of size (8, 8) and assign it to a variable called fig
fig, ax = plt.subplots(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# INPUT YOUR CODE HERE: Plot the Sun at the center
ax.scatter(0, 0, color="yellow", s=100, label="Sun")

# Plot orbits of planets
for i, planet in enumerate(planet_names):
    # Create a variable orbital_radius and assign it to the semi major axis value for each planet
    # Create a variable orbit_theta and assign it to a set of 100 equally spaced values from 0 to 2pi
    # Create a variable x and assign it to the x-axis values of each orbit
    # Create a variable y and assign it to the y-axis values of each orbit
    orbital_radius = semi_major_axis[i]
    orbit_theta = np.linspace(0, 2*math.pi, 100)
    x = orbital_radius * np.cos(orbit_theta)
    y = orbital_radius * np.sin(orbit_theta)
    z = np.zeros_like(x)
    ax.plot(x, y, z, label=planet)

# Set X, Y, and Z labels
# Set Title of Graph
# Initialize Graph Legend
ax.set_aspect('auto', 'box')
ax.set_xlabel("Distance(AU)")
ax.set_ylabel("DIstance(AU)")
ax.set_zlabel("Distance(AU)")
ax.legend()

# Show the Plot
plt.show()
